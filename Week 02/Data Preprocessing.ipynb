# %% [markdown]
# # Tutorial 02: Data Preprocessing
#
# The following tutorial contains Python examples for data preprocessing. You should refer first Lecture of Data Science to understand the some of the concepts introduced in this tutorial.
#
# Note: The notebook(.ipynb) can be downloaded from Google Classroom.
#
# Data preprocessing consists of a broad set of techniques for cleaning, selecting, and transforming data mining analysis. Read the step-by-step introductions below carefully. To execute the code, click on the corresponding cell and press the SHIFT-ENTER keys simultaneously.

# %% [markdown]
# ## 2.1. Data Quality Issues

# %% [markdown]
# Poor data quality can have an adverse effect on data mining. Among the common data quality issues include noise, outliers, missing values, and duplicate data. This section presents examples of Python code to alleviate some of these data quality problems. We begin with an example dataset from the UCI machine learning repository containing information about breast cancer patients. We will first download the dataset using Pandas read_csv() function and display its first 5 data points.

# %% [markdown]
# #### Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Import datset
#
# I am giving number to data set, as you can see because during pre-processing, I will change the data set very much from one to other. And I want you to have a track of the data sets in your notebook cell. So, each time you want to compare the data set, the stage can just go the notebook cell and check that.

# %%
data_set_01 = pd.read_csv('./Data_Set.csv')

# %% [markdown]
# #### Shape of my DataFrame

# %%
data_set_01.shape
# Out:
# (27, 6)

# %% [markdown]
# #### Get first 5 rows of Pandas DataFrame

# %%
data_set_01.head()
# Out:
#   Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                  Unit = kW and $/kW        NaN        NaN        NaN
# 1                                Time     E_Plug     E_Heat      Price
# 2                                   1         24         28         10
# 3                                   2         17         32         12
# 4                                   3         16         34         11
#
#     Unnamed: 4     Unnamed: 5
# 0          NaN            NaN
# 1  Temperature  No. Occupants
# 2          -15             12
# 3          -17             12
# 4          -19             12

# %% [markdown]
# #### Get last 5 rows of Pandas DataFrame

# %%
data_set_01.tail()
# Out:
#    Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 22                                  20        120         33         21
# 23                                  21         47         32         21
# 24                                  22         44         30         22
# 25                                  23         36         35          !
# 26                                  24         37         36         18
#
#    Unnamed: 4 Unnamed: 5
# 22        -12         12
# 23        -16         12
# 24        -18         12
# 25        -19         12
# 26        -22         12

# %% [markdown]
# As we can see here in our data set, the first two rows are the information about the data set
#
# 1. zero index show some information about the units that are in kilowatt.
#
# 2. The second row (Index 1) shows information about each columns/attributes.
#
# And, our initial job is to remove header and sample in 0th index to actually specify our data set with the header that we want. So, we define the header number for the pandas and that's how we can get rid of below information.
#
# 1. Name of the data = Home Consumption | Unnamed: 1 | Unnamed: 2 | Unnamed: 3 |Unnamed: 4 | Unnamed: 5
# 2. Unit = kW and $/kW |	NaN | NaN | NaN	| NaN | NaN

# %%
data_set_02 = pd.read_csv('./Data_Set.csv', header = 2) # python skip first two row
data_set_02.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0     1    24.0      28    10          -15             12
# 1     2    17.0      32    12          -17             12
# 2     3    16.0      34    11          -19             12
# 3     3    16.0      34    11          -19             12
# 4     4    16.0      33    12          -18             12

# %% [markdown]
# In our first dataframe named "data_set_01", we have 27 rows and in our second dataframe named "data_set_02" we have 25 rows.
#
# Two of the rows are removed and now we can see that our data set is actually look like a data set 😊.
#
# Header are:
#
# 1. Time
#
# 2. E_Plug
#
# 3. E_Heat
#
# 4. Price
#
# 5. Temperature
#
# 6. No. Occupants

# %%
print('The shape of data_set_01 -->', data_set_01.shape)
print('The shape of data_set_01 -->', data_set_02.shape)
# Out:
# The shape of data_set_01 --> (27, 6)
# The shape of data_set_01 --> (25, 6)

# %% [markdown]
# #### Change column name
#
# We can change any feature names "Column Names" as we like and it is very easy. We just make a dictionary.
#
# Key of the dictionary represent previous name. <br>
# And value of the dictionary represent new name.

# %%
data_set_03 = data_set_02.rename( columns = {'Temperature': 'Temp'} )
data_set_03.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp  No. Occupants
# 0     1    24.0      28    10   -15             12
# 1     2    17.0      32    12   -17             12
# 2     3    16.0      34    11   -19             12
# 3     3    16.0      34    11   -19             12
# 4     4    16.0      33    12   -18             12

# %% [markdown]
# #### Drop a column from a Pandas Dataframe

# %%
data_set_04 = data_set_03.drop('No. Occupants', axis = 1)
data_set_04.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18

# %% [markdown]
# Note: We don't have to save it each time into a new variable, drop () function has inplace parameter. When inplace = True , the data is modified in place, which means it will return nothing and the dataframe is now updated. When inplace = False , which is the default, then the operation is performed and it returns a copy of the object.

# %%
data_set_03.drop('No. Occupants', axis = 1, inplace = True)
data_set_03.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18

# %% [markdown]
# # Tutorial 02: Preprocessing Statistics

# %% [raw]
# In this session, we want to go after the statistics, depth into statistics, and I want to show some intution about the statistics.
#
# It is very easy and simple mathematical formulation. So we go after it with some examples and you will understand it better.

# %% [markdown]
# Mathematical Formulation with simple example:
#
# 1. Mean
# ($\bar{X}$) : $\sum_{i=1}^{n} \frac{x_i}{n}$ = $\frac{4 + 8 + 12 + 21 + 33 + 58 + 92 + 98}{8} = 40.75$
#
#
#
# 2. Variance (V) : $\sum_{i=1}^{n} \frac{(x_i -\bar{x})^2 }{n}$ = $\frac{ (4 - 40.75)^2  +  (8-40.75)^2 + (12-40.75)^2 + (21-40.75)^2 + (33-40.75)^2 + (58-40.75)^2 + (92-40.75)^2 + (98-40.75)^2}{8} = 1237.7$
#
#
#
# 3. Standard Deviation (σ) : $\sqrt{\sum_{i=1}^{n} \frac{(x_i -\bar{x})^2 }{n}}$ = $\sqrt{Variance(V)}$ = $\sqrt{1237.7} = 35.2 $
#
#
#
# 4. Median (M) = $\frac{21 + 33}{2} = 27 $

# %% [markdown]
#  # Tutorial 02: Drop Duplicate Rows

# %% [markdown]
# #### Find duplicate rows in a Dataframe
#
# In this article, we will be discussing about how to find duplicate rows in a Dataframe. For this we will use Dataframe.duplicated() method of Pandas.

# %%
duplicated = data_set_04[data_set_04.duplicated()]
duplicated
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 3     3    16.0      34    11   -19

# %% [markdown]
# #### Drop duplicate rows in a Dataframe

# %%
data_set_05 = data_set_04.drop(2, axis = 0)
data_set_05.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 3     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18
# 5     5    16.0      30    10   -14

# %% [markdown]
# #### Reset index

# %%
data_set_06 = data_set_05.reset_index()
data_set_06.head()
# Out:
#    index  Time  E_Plug  E_Heat Price  Temp
# 0      0     1    24.0      28    10   -15
# 1      1     2    17.0      32    12   -17
# 2      3     3    16.0      34    11   -19
# 3      4     4    16.0      33    12   -18
# 4      5     5    16.0      30    10   -14

# %% [markdown]
# If you set drop = True , reset_index will delete the index instead of inserting it back into the columns of the DataFrame. If you set drop = True , the current index will be deleted entirely and the numeric index will replace it.

# %%
data_set_07 = data_set_05.reset_index(drop = True)
data_set_07.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     4    16.0      33    12   -18
# 4     5    16.0      30    10   -14

# %% [markdown]
# Now, I want to tell pandas to go after this newly created data frame "data_set_07" and print the Mean, Variance, Co-Variance and Standard Deviation for me. So, I will understand my dataset better.
#
# For this I am using the  describe() method which is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.
#
# From this describe method () we can find some unusual things. For example,  we can find at column E_plug column has one less number. Or we can see that, for electricity of heat we have a minus number. So, our logic tells us that we can have minus electricity and we have problem in E_Heat.

# %%
data_set_07.describe()
# Out:
#             Time      E_Plug     E_Heat       Temp
# count  24.000000   23.000000  24.000000  24.000000
# mean   12.500000   31.521739  25.666667 -10.250000
# std     7.071068   21.336843   9.262672   7.968689
# min     1.000000   16.000000  -4.000000 -22.000000
# 25%     6.750000   20.500000  19.750000 -16.250000
# 50%    12.500000   27.000000  28.500000 -13.000000
# 75%    18.250000   34.500000  32.000000  -3.000000
# max    24.000000  120.000000  36.000000   3.000000

# %% [markdown]
# #### Spot abnormal number

# %%
min_item = data_set_07['E_Heat'].min()
min_item
# Out:
# -4

# %% [markdown]
# #### Locate min item

# %%
data_set_07['E_Heat'][data_set_07['E_Heat'] == min_item]
# Out:
# 16   -4
# Name: E_Heat, dtype: int64

# %% [markdown]
# ### replace abnormal number with some other number

# %%
data_set_07['E_Heat'].replace(-4, 21, inplace = True)

# %%
data_set_07[12:18]
# Out:
#     Time  E_Plug  E_Heat Price  Temp
# 12    13    30.0      19    16     0
# 13    14     NaN      13    17     2
# 14    15    27.0      14    17     3
# 15    16    27.0      16    17     2
# 16    17    28.0      21    18     0
# 17    18    33.0      26    20    -6

# %% [markdown]
#  # Tutorial 02: Pre-Processing Covariance
#
# Covariance shows the relation between the variables (features). And, covariance formula measures the correlation between two variables.
#
# Formula to measure co-relation between two variables=  $ \frac{\sum(X - \bar{X}) (Y - \bar{Y})}{n}$

# %% [markdown]
# Graph to show co-relation between two variables
# ![co_variance.png](attachment:co_variance.png)

# %% [markdown]
# ## Covariance of our dataset

# %%
data_set_07.cov()
# Out:
#              Time      E_Plug     E_Heat       Temp
# Time    50.000000   88.535573  -0.500000   8.217391
# E_Plug  88.535573  455.260870  25.833992   0.154150
# E_Heat  -0.500000   25.833992  47.346014 -51.206522
# Temp     8.217391    0.154150 -51.206522  63.500000

# %%
co_relation = data_set_07.cov()
co_relation
# Out:
#              Time      E_Plug     E_Heat       Temp
# Time    50.000000   88.535573  -0.500000   8.217391
# E_Plug  88.535573  455.260870  25.833992   0.154150
# E_Heat  -0.500000   25.833992  47.346014 -51.206522
# Temp     8.217391    0.154150 -51.206522  63.500000

# %% [markdown]
# ## Visualization covariance matrix

# %%
import seaborn as sns

# %%
sns.heatmap(data_set_07.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
#  # Tutorial 02: PreProcessing Missing Values

# %% [markdown]
# It is not unusual for an object to be missing one or more attribute values. In some cases, the information was not collected; while in other cases, some attributes are inapplicable to the data instances. This section presents examples on the different approaches for handling missing values. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA(Not Available) values in pandas.
#
# According to the description of the data, the one missing values are encoded as '!' in the original data of Price column. Our first task is to convert the missing values to NaNs. We can then count the number of missing values in each column of the data.
#
# After converting missing value to NaN, missing data is represented by two value:
#
# 1. None: None is a Python singleton object that is often used for missing data in Python code.
#
#
# 2. NaN : NaN (an acronym for Not a Number), is a special floating-point value recognized by all systems that use the standard IEEE floating-point representation.

# %%
data_set_08 = data_set_07.replace('!', np.NaN)

print('Number of instances = %d' % (data_set_08.shape[0]))
print('Number of attributes = %d' % (data_set_08.shape[1]))

print('Number of missing values:')
for col in data_set_08.columns:
    print('\t%s: %d' % (col,data_set_08[col].isna().sum()))
# Out:
# Number of instances = 24
# Number of attributes = 5
# Number of missing values:
# 	Time: 0
# 	E_Plug: 1
# 	E_Heat: 0
# 	Price: 1
# 	Temp: 0

# %% [markdown]
# ### Get a concise summary of the dataframe
#
# Now, we have two NaN in our data set. But, the problem is that exclamation mark "!" made my Price column as a categotical variable not the numerical. So, I should change this to numeric as well then go after further preprocessing of our data set.

# %%
data_set_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    24 non-null     int64
#  1   E_Plug  23 non-null     float64
#  2   E_Heat  24 non-null     int64
#  3   Price   23 non-null     object
#  4   Temp    24 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ### convert categorical variable to numeric

# %%
data_set_08['Price'] = data_set_08.apply(pd.to_numeric)

# %%
data_set_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    24 non-null     int64
#  1   E_Plug  23 non-null     float64
#  2   E_Heat  24 non-null     int64
#  3   Price   24 non-null     float64
#  4   Temp    24 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 1.1 KB

# %% [markdown]
# ### Handling Missing Data Easily
#
# We basically have three different techniques of handling missing data.
#
# 1. Just delete the record which has missing values
#
# 2. Create a seperate model to handle the missing value
#
# 3. Impute missing values with Mean, Median, and Mode values

# %% [markdown]
# #### Drop row using index number

# %%
data_set_08.drop(13, axis = 0 )
# Out:
#     Time  E_Plug  E_Heat  Price  Temp
# 0      1    24.0      28    1.0   -15
# 1      2    17.0      32    2.0   -17
# 2      3    16.0      34    3.0   -19
# 3      4    16.0      33    4.0   -18
# 4      5    16.0      30    5.0   -14
# 5      6    16.0      31    6.0   -16
# 6      7    19.0      28    7.0   -14
# 7      8    22.0      29    8.0   -15
# 8      9    25.0      26    9.0   -12
# 9     10    26.0      24   10.0    -8
# 10    11    27.0      20   11.0    -4
# 11    12    30.0      19   12.0     0
# 12    13    30.0      19   13.0     0
# 14    15    27.0      14   15.0     3
# 15    16    27.0      16   16.0     2
# 16    17    28.0      21   17.0     0
# 17    18    33.0      26   18.0    -6
# 18    19    42.0      32   19.0    -8
# 19    20   120.0      33   20.0   -12
# 20    21    47.0      32   21.0   -16
# 21    22    44.0      30   22.0   -18
# 22    23    36.0      35   23.0   -19
# 23    24    37.0      36   24.0   -22

# %% [markdown]
# #### Drop all the NaN cell

# %%
data_set_08.dropna(axis = 0) `
# Out:
#     Time  E_Plug  E_Heat  Price  Temp
# 0      1    24.0      28    1.0   -15
# 1      2    17.0      32    2.0   -17
# 2      3    16.0      34    3.0   -19
# 3      4    16.0      33    4.0   -18
# 4      5    16.0      30    5.0   -14
# 5      6    16.0      31    6.0   -16
# 6      7    19.0      28    7.0   -14
# 7      8    22.0      29    8.0   -15
# 8      9    25.0      26    9.0   -12
# 9     10    26.0      24   10.0    -8
# 10    11    27.0      20   11.0    -4
# 11    12    30.0      19   12.0     0
# 12    13    30.0      19   13.0     0
# 14    15    27.0      14   15.0     3
# 15    16    27.0      16   16.0     2
# 16    17    28.0      21   17.0     0
# 17    18    33.0      26   18.0    -6
# 18    19    42.0      32   19.0    -8
# 19    20   120.0      33   20.0   -12
# 20    21    47.0      32   21.0   -16
# 21    22    44.0      30   22.0   -18
# 22    23    36.0      35   23.0   -19
# 23    24    37.0      36   24.0   -22

# %% [markdown]
# #### Replace NA or NaN values in the DataFrame with the specified values using fillna() method
#
# Info of Pandas fillna() method:
#
# 1. method='ffill': Ffill or forward-fill propagates the last observed non-null value forward until another non-null value is encountered.
#
#
# 2. method='bfill': Bfill or backward-fill propagates the first observed non-null value backward until another non-null value is met.

# %%
data_set_08.fillna(method='ffill')
# Out:
#     Time  E_Plug  E_Heat  Price  Temp
# 0      1    24.0      28    1.0   -15
# 1      2    17.0      32    2.0   -17
# 2      3    16.0      34    3.0   -19
# 3      4    16.0      33    4.0   -18
# 4      5    16.0      30    5.0   -14
# 5      6    16.0      31    6.0   -16
# 6      7    19.0      28    7.0   -14
# 7      8    22.0      29    8.0   -15
# 8      9    25.0      26    9.0   -12
# 9     10    26.0      24   10.0    -8
# 10    11    27.0      20   11.0    -4
# 11    12    30.0      19   12.0     0
# 12    13    30.0      19   13.0     0
# 13    14    30.0      13   14.0     2
# 14    15    27.0      14   15.0     3
# 15    16    27.0      16   16.0     2
# 16    17    28.0      21   17.0     0
# 17    18    33.0      26   18.0    -6
# 18    19    42.0      32   19.0    -8
# 19    20   120.0      33   20.0   -12
# 20    21    47.0      32   21.0   -16
# 21    22    44.0      30   22.0   -18
# 22    23    36.0      35   23.0   -19
# 23    24    37.0      36   24.0   -22

# %%
data_set_08.fillna(method = 'bfill')
# Out:
#     Time  E_Plug  E_Heat  Price  Temp
# 0      1    24.0      28    1.0   -15
# 1      2    17.0      32    2.0   -17
# 2      3    16.0      34    3.0   -19
# 3      4    16.0      33    4.0   -18
# 4      5    16.0      30    5.0   -14
# 5      6    16.0      31    6.0   -16
# 6      7    19.0      28    7.0   -14
# 7      8    22.0      29    8.0   -15
# 8      9    25.0      26    9.0   -12
# 9     10    26.0      24   10.0    -8
# 10    11    27.0      20   11.0    -4
# 11    12    30.0      19   12.0     0
# 12    13    30.0      19   13.0     0
# 13    14    27.0      13   14.0     2
# 14    15    27.0      14   15.0     3
# 15    16    27.0      16   16.0     2
# 16    17    28.0      21   17.0     0
# 17    18    33.0      26   18.0    -6
# 18    19    42.0      32   19.0    -8
# 19    20   120.0      33   20.0   -12
# 20    21    47.0      32   21.0   -16
# 21    22    44.0      30   22.0   -18
# 22    23    36.0      35   23.0   -19
# 23    24    37.0      36   24.0   -22

# %% [markdown]
# #### Impute missing values with Mean, Median, and Mode values
